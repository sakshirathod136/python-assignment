# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshirathod136/python-assignment/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to check whether input is number or character

x = '8'

print("Given input:", x)

if x.isdigit():
    print("It is a Number")
else:
    print("It is a Character")
# Out:
# Given input: 8
# It is a Number
