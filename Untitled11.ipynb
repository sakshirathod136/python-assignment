# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshirathod136/python-assignment/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 15
b = 25
sum = a + b
print("Sum =", sum)
# Out:
# Sum = 40
